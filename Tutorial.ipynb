# %% [markdown]
# ## 1. Activar Entorno

# %%
cd "put your path here wey"
source app_transporte/bin/activate
pip install -r requirements.txt

# %% [markdown]
# ## 2. Iniciar MongoDB

# %% [markdown]
# mac:

# %%
brew services start mongodb-community@8.0
brew services list | grep mongodb

# %% [markdown]
# ### Probar conexión

# %%
mongosh "mongodb://localhost:27017/"

# %% [markdown]
# ### Dentro de mongosh, pa ver collections

# %%
use app_transporte
show collections

# %% [markdown]
# ## 3. Configurar Variables

# %%
export MONGO_URI="mongodb://localhost:27017/"
export MONGO_DB_NAME="app_transporte"

# %% [markdown]
# ## 4. Crear Primer Admin

# %% [markdown]
# solicitara los mismos datos que el login habitual. Con la diferencia que toda cuenta hecha desde create_admin.py poseera privilegios de admin

# %%
python3 scripts/create_admin.py

# %% [markdown]
# ## 5. Ejecutar App

# %%
python3 app.py

# %% [markdown]
# Al ejecutar el app.py te dara una ip estatica, es la misma que la ip aqui abajo, pero siempre es mejor probar con la que te de terminal, solo es copiar y pegar en tu buscador de preferencia

# %%
http://127.0.0.1:5000
